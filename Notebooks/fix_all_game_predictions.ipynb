# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from nba_helper import read_url_to_csv, read_data
from preprocess import *
from nba_helper import elo_url
from pymongo import MongoClient
client = MongoClient('localhost', 27017)
db = client['NBA']

db.list_collection_names()
# Out:
# ['historical_raptor', 'player2k', 'game_log', 'shot_chart']

# %%
historical_pbp = pd.read_csv('../Data/historical_pbp.csv')

# %%
def feature_engineer(df):
    pbp = df.copy()
    pbp[['home_true', 'visitor_true']] = pbp[['HOMEDESCRIPTION','VISITORDESCRIPTION']].notnull().astype(int)
    pbp['block'] = pbp['HOMEDESCRIPTION'].str.contains("BLOCK").fillna(False)
    pbp['steal'] = pbp['HOMEDESCRIPTION'].str.contains("STEAL").fillna(False)

    pbp['home_poss'] = pbp.apply(home_poss, axis = 1)
    pbp['diff'] = pbp['SCOREMARGIN'].ffill().fillna(0).replace({'TIE':0}).astype(int)
    pbp['OT_ind'] = (pbp['PERIOD']-4).clip(lower=0)

    pbp['seconds'] = pbp['PCTIMESTRING'].apply(str_to_time)
    pbp['seconds_left_in_game_from_quarter'] = pbp['PERIOD'].apply(find_seconds_left)
    pbp['time_remaining'] = pbp['seconds'] + pbp['seconds_left_in_game_from_quarter']

    game = pbp[['GAME_ID', 'home_poss', 'diff', 'time_remaining', 'OT_ind']]
    
    return game

# %%
historical_pbp_modelled = historical_pbp.groupby('GAME_ID').apply(feature_engineer)
historical_pbp_modelled = historical_pbp_modelled.reset_index(drop=True)

# %%
elo = read_url_to_csv(elo_url)
elo = elo[elo['date'] > '2012-01-01']

elo.loc[:, 'elo_difference'] = np.abs(elo['elo1_pre'] - elo['elo2_pre'])

elo = elo[['date', 'team1', 'elo1_pre', 'elo2_pre', 'elo_difference']]

elo['team1'] = elo['team1'].replace({'BRK':'BKN',
                                     'PHO':'PHX',
                                    'CHO':'CHA',})

# %%
all_games = pd.DataFrame.from_records(db.game_log.find())
all_games[['Home', 'Away']] = all_games['MATCHUP'].str.split('vs.', expand=True)
all_games['Home'] = all_games['Home'].str.strip()
all_games['GAME_ID'] = all_games['GAME_ID'].astype(int)
all_games['home_team_win'] = all_games['WL'].replace({'W':1, 'L':0})

# %%
elo_w_game_ids = all_games.merge(elo, left_on=['GAME_DATE', 'Home'], 
                                 right_on = ['date', 'team1'])

# %%
df = historical_pbp_modelled.merge(elo_w_game_ids[['GAME_ID', 'elo1_pre', 
                                                   'elo2_pre', 'home_team_win',
                                                  'MATCHUP', ]], on = ['GAME_ID'])

# %%
# from pymongo import MongoClient, ASCENDING, DESCENDING

# db.game_log.insert_many(all_games.to_dict('records'))

# db.game_log.create_index([("GAME_ID", ASCENDING)], unique=True)

# %%
df
# Out:
#           GAME_ID  home_poss  diff  time_remaining  OT_ind     elo1_pre  \
# 0        21500001          0     0            2880       0  1561.843550
# 1        21500001          1     0            2880       0  1561.843550
# 2        21500001          1     0            2861       0  1561.843550
# 3        21500001          1     0            2859       0  1561.843550
# 4        21500001          1     0            2857       0  1561.843550
# ...           ...        ...   ...             ...     ...          ...
# 3553191  22100581          0    17              34       0  1694.385602
# 3553192  22100581          0    17              31       0  1694.385602
# 3553193  22100581          0    17              23       0  1694.385602
# 3553194  22100581          1    17              18       0  1694.385602
# 3553195  22100581          0    17               0       0  1694.385602
#
#             elo2_pre  home_team_win      MATCHUP
# 0        1472.058800            0.0  ATL vs. DET
# 1        1472.058800            0.0  ATL vs. DET
# 2        1472.058800            0.0  ATL vs. DET
# 3        1472.058800            0.0  ATL vs. DET
# 4        1472.058800            0.0  ATL vs. DET
# ...              ...            ...          ...
# 3553191  1490.689779            1.0  PHX vs. LAC
# 3553192  1490.689779            1.0  PHX vs. LAC
# 3553193  1490.689779            1.0  PHX vs. LAC
# 3553194  1490.689779            1.0  PHX vs. LAC
# 3553195  1490.689779            1.0  PHX vs. LAC
#
# [3553196 rows x 9 columns]

# %%
modelling_data_wO_elo = df[['home_poss', 'diff', 'time_remaining', 'OT_ind']]
modelling_data_w_elo = df[['home_poss', 'diff', 'time_remaining', 'OT_ind', 'elo1_pre', 'elo2_pre']]
modelling_target = df[['home_team_win']]

# %%
model_wO_elo = tf.keras.models.Sequential([
    tf.keras.layers.Dense(12, activation='relu', input_shape=[4,]),
    tf.keras.layers.Dense(12, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model_wO_elo.compile(optimizer=tf.keras.optimizers.RMSprop(1e-3), loss='binary_crossentropy', metrics=['accuracy', 'AUC'])
model_wO_elo.summary()

model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(12, activation='relu', input_shape=[6,]),
    tf.keras.layers.Dense(12, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(optimizer=tf.keras.optimizers.RMSprop(1e-3), loss='binary_crossentropy', metrics=['accuracy', 'AUC'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 12)                60
#
#  dense_13 (Dense)            (None, 12)                156
#
#  dense_14 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 229
# Trainable params: 229
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 12)                84
#
#  dense_16 (Dense)            (None, 12)                156
#
#  dense_17 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 253
# Trainable params: 253
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_wO_elo.fit(modelling_data_wO_elo.values,
          modelling_target.values,
          verbose=1,
          shuffle=True,
          epochs=15,
          batch_size=512)

model.fit(modelling_data_w_elo.values,
          modelling_target.values,
          verbose=1,
          shuffle=True,
          epochs=15,
          batch_size=512)
# Out:
# Epoch 1/15
# 6940/6940 [==============================] - 6s 704us/step - loss: 1.5905 - accuracy: 0.6787 - auc: 0.7143
# Epoch 2/15
# 6940/6940 [==============================] - 5s 695us/step - loss: 0.8838 - accuracy: 0.6892 - auc: 0.7454
# Epoch 3/15
# 6940/6940 [==============================] - 5s 696us/step - loss: 0.5084 - accuracy: 0.7307 - auc: 0.8127
# Epoch 4/15
# 6940/6940 [==============================] - 5s 706us/step - loss: 0.4903 - accuracy: 0.7403 - auc: 0.8259
# Epoch 5/15
# 6940/6940 [==============================] - 5s 698us/step - loss: 0.4901 - accuracy: 0.7405 - auc: 0.8262
# Epoch 6/15
# 6940/6940 [==============================] - 5s 705us/step - loss: 0.4895 - accuracy: 0.7407 - auc: 0.8266
# Epoch 7/15
# 6940/6940 [==============================] - 5s 713us/step - loss: 0.4897 - accuracy: 0.7407 - auc: 0.8266
# Epoch 8/15
# 6940/6940 [==============================] - 5s 715us/step - loss: 0.4900 - accuracy: 0.7410 - auc: 0.8266
# Epoch 9/15
# 6940/6940 [==============================] - 5s 705us/step - loss: 0.4899 - accuracy: 0.7411 - auc: 0.8268
# Epoch 10/15
# 6940/6940 [==============================] - 5s 705us/step - loss: 0.4909 - accuracy: 0.7408 - auc: 0.8265
# Epoch 11/15
# 6940/6940 [==============================] - 5s 707us/step - loss: 0.4908 - accuracy: 0.7409 - auc: 0.8266
# Epoch 12/15
# 6940/6940 [==============================] - 5s 709us/step - loss: 0.4889 - accuracy: 0.7412 - auc: 0.8270
# Epoch 13/15
# 6940/6940 [==============================] - 5s 738us/step - loss: 0.4892 - accuracy: 0.7412 - auc: 0.8270
# Epoch 14/15
# 6940/6940 [==============================] - 5s 721us/step - loss: 0.4895 - accuracy: 0.7411 - auc: 0.8269
# Epoch 15/15
# 6940/6940 [==============================] - 5s 718us/step - loss: 0.4896 - accuracy: 0.7413 - auc: 0.8268
# Epoch 1/15
# 6940/6940 [==============================] - 6s 815us/step - loss: 2.9217 - accuracy: 0.6762 - auc: 0.7214
# Epoch 2/15
# 6940/6940 [==============================] - 6s 848us/step - loss: 0.4998 - accuracy: 0.7499 - auc: 0.8306
# Epoch 3/15
# 6940/6940 [==============================] - 6s 808us/step - loss: 0.4655 - accuracy: 0.7644 - auc: 0.8496
# Epoch 4/15
# 6940/6940 [==============================] - 5s 784us/step - loss: 0.4633 - accuracy: 0.7649 - auc: 0.8508
# Epoch 5/15
# 6940/6940 [==============================] - 6s 841us/step - loss: 0.4622 - accuracy: 0.7656 - auc: 0.8515
# Epoch 6/15
# 6940/6940 [==============================] - 6s 839us/step - loss: 0.4617 - accuracy: 0.7657 - auc: 0.8520
# Epoch 7/15
# 6940/6940 [==============================] - 7s 944us/step - loss: 0.4614 - accuracy: 0.7660 - auc: 0.8521
# Epoch 8/15
# 6940/6940 [==============================] - 6s 827us/step - loss: 0.4611 - accuracy: 0.7665 - auc: 0.8524
# Epoch 9/15
# 6940/6940 [==============================] - 5s 792us/step - loss: 0.4608 - accuracy: 0.7665 - auc: 0.8525
# Epoch 10/15
# 6940/6940 [==============================] - 6s 799us/step - loss: 0.4604 - accuracy: 0.7669 - auc: 0.8528
# Epoch 11/15
# 6940/6940 [==============================] - 6s 805us/step - loss: 0.4602 - accuracy: 0.7669 - auc: 0.8530
# Epoch 12/15
# 6940/6940 [==============================] - 5s 746us/step - loss: 0.4599 - accuracy: 0.7671 - auc: 0.8532
# Epoch 13/15
# 6940/6940 [==============================] - 5s 746us/step - loss: 0.4596 - accuracy: 0.7673 - auc: 0.8533
# Epoch 14/15
# 6940/6940 [==============================] - 5s 742us/step - loss: 0.4595 - accuracy: 0.7672 - auc: 0.8534
# Epoch 15/15
# 6940/6940 [==============================] - 5s 748us/step - loss: 0.4595 - accuracy: 0.7673 - auc: 0.8534

# %%
model.save('../Models/TF_model_w_elo.h5')
model_wO_elo.save('../Models/TF_model_wO_elo.h5')

# %%
df.loc[:, 'preds_w_elo'] = model.predict_on_batch(df[modelling_data_w_elo.columns])

df.loc[:, 'preds_wO_elo'] = model_wO_elo.predict_on_batch(df[modelling_data_wO_elo.columns])

# %%
df
# Out:
#           GAME_ID  home_poss  diff  time_remaining  OT_ind  ...     elo2_pre  \
# 0        21500001          0     0            2880       0  ...  1472.058800
# 1        21500001          1     0            2880       0  ...  1472.058800
# 2        21500001          1     0            2861       0  ...  1472.058800
# 3        21500001          1     0            2859       0  ...  1472.058800
# 4        21500001          1     0            2857       0  ...  1472.058800
# ...           ...        ...   ...             ...     ...  ...          ...
# 3553191  22100581          0    17              34       0  ...  1490.689779
# 3553192  22100581          0    17              31       0  ...  1490.689779
# 3553193  22100581          0    17              23       0  ...  1490.689779
# 3553194  22100581          1    17              18       0  ...  1490.689779
# 3553195  22100581          0    17               0       0  ...  1490.689779
#
#          home_team_win      MATCHUP preds_w_elo  preds_wO_elo
# 0                  0.0  ATL vs. DET    0.690017      0.562178
# 1                  0.0  ATL vs. DET    0.688084      0.562178
# 2                  0.0  ATL vs. DET    0.687846      0.562178
# 3                  0.0  ATL vs. DET    0.687821      0.562178
# 4                  0.0  ATL vs. DET    0.687796      0.562178
# ...                ...          ...         ...           ...
# 3553191            1.0  PHX vs. LAC    0.999997      1.000000
# 3553192            1.0  PHX vs. LAC    0.999997      1.000000
# 3553193            1.0  PHX vs. LAC    0.999998      1.000000
# 3553194            1.0  PHX vs. LAC    0.999999      1.000000
# 3553195            1.0  PHX vs. LAC    0.999999      1.000000
#
# [3553196 rows x 11 columns]

# %%
historical_pbp
# Out:
#           GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  ...  \
# 0        21500003         0            12                   0       1  ...
# 1        21500003         1            10                   0       1  ...
# 2        21500003         2             2                   1       1  ...
# 3        21500003         3             4                   0       1  ...
# 4        21500003         4             1                   1       1  ...
# ...           ...       ...           ...                 ...     ...  ...
# 3553191  22100581       666             2                   1       4  ...
# 3553192  22100581       667             4                   0       4  ...
# 3553193  22100581       669             2                   1       4  ...
# 3553194  22100581       670             4                   0       4  ...
# 3553195  22100581       671            13                   0       4  ...
#
#         PLAYER3_TEAM_ID PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 0                   NaN               NaN                   NaN
# 1          1.610613e+09       New Orleans              Pelicans
# 2                   NaN               NaN                   NaN
# 3                   NaN               NaN                   NaN
# 4                   NaN               NaN                   NaN
# ...                 ...               ...                   ...
# 3553191             NaN               NaN                   NaN
# 3553192             NaN               NaN                   NaN
# 3553193             NaN               NaN                   NaN
# 3553194             NaN               NaN                   NaN
# 3553195             NaN               NaN                   NaN
#
#         PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG
# 0                             NaN                    0
# 1                             NOP                    1
# 2                             NaN                    1
# 3                             NaN                    1
# 4                             NaN                    1
# ...                           ...                  ...
# 3553191                       NaN                    1
# 3553192                       NaN                    0
# 3553193                       NaN                    1
# 3553194                       NaN                    1
# 3553195                       NaN                    1
#
# [3553196 rows x 34 columns]

# %%
db.list_collection_names()
# Out:
# ['historical_raptor', 'player2k', 'shot_chart', 'game_log']

# %%
from pymongo import MongoClient, ASCENDING, DESCENDING

db.historical_pbp.insert_many(historical_pbp.to_dict('records'))

db.historical_pbp.create_index([("GAME_ID", ASCENDING)])
# Out:
# 'GAME_ID_1'

# %%
db.historical_pbp_modelled.insert_many(df.to_dict('records'))

db.historical_pbp_modelled.create_index([("GAME_ID", ASCENDING)])
# Out:
# 'GAME_ID_1'

# %%
test = pd.DataFrame.from_records(db.historical_pbp.find({'GAME_ID': 22100581}))

# %%
test
# Out:
#                           _id   GAME_ID  EVENTNUM  EVENTMSGTYPE  \
# 0    61e9efd6f0ee3d9953e21db9  22100581         2            12
# 1    61e9efd6f0ee3d9953e21dba  22100581         4            10
# 2    61e9efd6f0ee3d9953e21dbb  22100581         7             2
# 3    61e9efd6f0ee3d9953e21dbc  22100581         8             4
# 4    61e9efd6f0ee3d9953e21dbd  22100581         9             2
# ..                        ...       ...       ...           ...
# 471  61e9efd6f0ee3d9953e21f90  22100581       666             2
# 472  61e9efd6f0ee3d9953e21f91  22100581       667             4
# 473  61e9efd6f0ee3d9953e21f92  22100581       669             2
# 474  61e9efd6f0ee3d9953e21f93  22100581       670             4
# 475  61e9efd6f0ee3d9953e21f94  22100581       671            13
#
#      EVENTMSGACTIONTYPE  ...  PLAYER3_TEAM_ID PLAYER3_TEAM_CITY  \
# 0                     0  ...              NaN               NaN
# 1                     0  ...     1.610613e+09           Phoenix
# 2                   101  ...              NaN               NaN
# 3                     0  ...              NaN               NaN
# 4                     1  ...              NaN               NaN
# ..                  ...  ...              ...               ...
# 471                   1  ...              NaN               NaN
# 472                   0  ...              NaN               NaN
# 473                   1  ...              NaN               NaN
# 474                   0  ...              NaN               NaN
# 475                   0  ...              NaN               NaN
#
#     PLAYER3_TEAM_NICKNAME PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG
# 0                     NaN                       NaN                    0
# 1                    Suns                       PHX                    1
# 2                     NaN                       NaN                    1
# 3                     NaN                       NaN                    1
# 4                     NaN                       NaN                    1
# ..                    ...                       ...                  ...
# 471                   NaN                       NaN                    1
# 472                   NaN                       NaN                    0
# 473                   NaN                       NaN                    1
# 474                   NaN                       NaN                    1
# 475                   NaN                       NaN                    1
#
# [476 rows x 35 columns]

# %%
import pandas as pd
import numpy as np
from nba_api.stats.endpoints import playbyplayv2, leaguegamelog, leaguegamefinder

lgl = leaguegamelog.LeagueGameLog().get_data_frames()[0].astype({'GAME_ID':int})
