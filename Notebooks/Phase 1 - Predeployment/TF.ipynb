# %%
import sqlite3
import pandas as pd
import numpy as np

from sklearn.preprocessing import normalize
import pickle 
from nba_api.stats.endpoints import playbyplayv2, leaguegamefinder
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

from nba_helper import read_url_to_csv, read_data

from nba_helper import elo_url

import pandas as pd
from pymongo import MongoClient

client = MongoClient('localhost', 27017)
db = client['NBA']

db.list_collection_names()
# Out:
# ['historical_raptor',
#  'player2k',
#  'game_log',
#  'shot_chart',
#  'historical_pbp_modelled',
#  'historical_pbp']

# %%
pbp = pd.DataFrame.from_records(db.historical_pbp.find())

# %%
pbp.head()
# Out:
#                         _id   GAME_ID  EVENTNUM  EVENTMSGTYPE  \
# 0  61d614c5f040a069488214dc  21500003         0            12
# 1  61d614c5f040a069488214dd  21500003         1            10
# 2  61d614c5f040a069488214de  21500003         2             2
# 3  61d614c5f040a069488214df  21500003         3             4
# 4  61d614c5f040a069488214e0  21500003         4             1
#
#    EVENTMSGACTIONTYPE  PERIOD WCTIMESTRING PCTIMESTRING  \
# 0                   0       1     11:03 PM        12:00
# 1                   0       1     11:03 PM        12:00
# 2                   1       1     11:03 PM        11:46
# 3                   0       1     11:03 PM        11:45
# 4                   1       1     11:03 PM        11:35
#
#                                     HOMEDESCRIPTION  \
# 0                                              None
# 1        Jump Ball Bogut vs. Davis: Tip to Robinson
# 2                                              None
# 3                       Bogut REBOUND (Off:0 Def:1)
# 4  Green 26' 3PT Jump Shot (3 PTS) (Thompson 1 AST)
#
#                    NEUTRALDESCRIPTION         VISITORDESCRIPTION  SCORE  \
# 0  Start of 1st Period (11:03 PM EST)                       None   None
# 1                                None                       None   None
# 2                                None  MISS Davis  3PT Jump Shot   None
# 3                                None                       None   None
# 4                                None                       None  0 - 3
#
#   SCOREMARGIN  PERSON1TYPE  PLAYER1_ID    PLAYER1_NAME  PLAYER1_TEAM_ID  \
# 0        None          0.0           0            None              NaN
# 1        None          4.0      101106    Andrew Bogut     1.610613e+09
# 2        None          5.0      203076   Anthony Davis     1.610613e+09
# 3        None          4.0      101106    Andrew Bogut     1.610613e+09
# 4           3          4.0      203110  Draymond Green     1.610613e+09
#
#   PLAYER1_TEAM_CITY PLAYER1_TEAM_NICKNAME PLAYER1_TEAM_ABBREVIATION  \
# 0              None                  None                      None
# 1      Golden State              Warriors                       GSW
# 2       New Orleans              Pelicans                       NOP
# 3      Golden State              Warriors                       GSW
# 4      Golden State              Warriors                       GSW
#
#    PERSON2TYPE  PLAYER2_ID   PLAYER2_NAME  PLAYER2_TEAM_ID PLAYER2_TEAM_CITY  \
# 0            0           0           None              NaN              None
# 1            5      203076  Anthony Davis     1.610613e+09       New Orleans
# 2            0           0           None              NaN              None
# 3            0           0           None              NaN              None
# 4            4      202691  Klay Thompson     1.610613e+09      Golden State
#
#   PLAYER2_TEAM_NICKNAME PLAYER2_TEAM_ABBREVIATION  PERSON3TYPE  PLAYER3_ID  \
# 0                  None                      None            0           0
# 1              Pelicans                       NOP            5      101126
# 2                  None                      None            0           0
# 3                  None                      None            0           0
# 4              Warriors                       GSW            0           0
#
#     PLAYER3_NAME  PLAYER3_TEAM_ID PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 0           None              NaN              None                  None
# 1  Nate Robinson     1.610613e+09       New Orleans              Pelicans
# 2           None              NaN              None                  None
# 3           None              NaN              None                  None
# 4           None              NaN              None                  None
#
#   PLAYER3_TEAM_ABBREVIATION  VIDEO_AVAILABLE_FLAG
# 0                      None                     0
# 1                       NOP                     1
# 2                      None                     1
# 3                      None                     1
# 4                      None                     1

# %%
pbp.shape
# Out:
# (3553196, 35)

# %%
pbp = pbp.drop('_id', axis = 1)

# %%
pbp.to_csv('../Data/historical_pbp.csv', index=False)

# %%
# %%time
pbp_prepped = feature_engineer(pbp)
# Out:
# CPU times: user 1min 22s, sys: 58.3 s, total: 2min 20s
# Wall time: 2min 54s

# %%
elo = read_url_to_csv(elo_url)
elo = elo[elo['date'] > '2012-01-01']

elo.loc[:, 'elo_difference'] = np.abs(elo['elo1_pre'] - elo['elo2_pre'])

elo = elo[['date', 'team1', 'elo1_pre', 'elo2_pre', 'elo_difference']]

elo['team1'] = elo['team1'].replace({'BRK':'BKN',
                                     'PHO':'PHX',
                                    'CHO':'CHA',})

# %%
all_games = pd.DataFrame.from_records(db.game_log.find())

# %%
all_games[['Home', 'Away']] = all_games['MATCHUP'].str.split('vs.', expand=True)
all_games['Home'] = all_games['Home'].str.strip()
all_games['GAME_ID'] = all_games['GAME_ID'].astype(int)
all_games['home_team_win'] = all_games['WL'].replace({'W':1, 'L':0})

# %%
elo_w_game_ids = all_games.merge(elo, left_on=['GAME_DATE', 'Home'], right_on = ['date', 'team1'])

# %%
df = pbp_prepped.merge(elo_w_game_ids[['GAME_ID', 'elo1_pre', 'elo2_pre', 'elo_difference', 'home_team_win']], on = ['GAME_ID'])

# %%
df.head()
# Out:
#     GAME_ID  home_poss  diff  time_remaining  OT_ind     elo1_pre  \
# 0  21500003          0     0            2880       0  1742.966075
# 1  21500003          1     0            2880       0  1742.966075
# 2  21500003          0     0            2866       0  1742.966075
# 3  21500003          1     0            2865       0  1742.966075
# 4  21500003          1     3            2855       0  1742.966075
#
#       elo2_pre  elo_difference  home_team_win
# 0  1521.178175        221.7879              1
# 1  1521.178175        221.7879              1
# 2  1521.178175        221.7879              1
# 3  1521.178175        221.7879              1
# 4  1521.178175        221.7879              1

# %%
# db.historical_pbp_modelled.insert_many(df.to_dict('records'))

# %%
db.list_collection_names()
# Out:
# ['historical_raptor',
#  'player2k',
#  'game_log',
#  'shot_chart',
#  'historical_pbp_modelled',
#  'historical_pbp']

# %%
games = df['GAME_ID'].unique()

# %%
train_games = games[:7000]
test_games = games[7000:]
train = df[df['GAME_ID'].isin(train_games)].drop(['GAME_ID', 'elo_difference'], axis = 1)

X_train = train.drop(['home_team_win'], axis = 1)
y_train = train['home_team_win']


test = df[df['GAME_ID'].isin(test_games)]

X_test = test.drop(['home_team_win', 'GAME_ID'], axis = 1)
y_test = test['home_team_win']

# %%
model_wO_elo = tf.keras.models.Sequential([
    tf.keras.layers.Dense(12, activation='relu', input_shape=[4,]),
    tf.keras.layers.Dense(12, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model_wO_elo.compile(optimizer=tf.keras.optimizers.RMSprop(1e-3), loss='binary_crossentropy', metrics=['accuracy', 'AUC'])
model_wO_elo.summary()

model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(12, activation='relu', input_shape=[6,]),
    tf.keras.layers.Dense(12, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(optimizer=tf.keras.optimizers.RMSprop(1e-3), loss='binary_crossentropy', metrics=['accuracy', 'AUC'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12)                60
#
#  dense_1 (Dense)             (None, 12)                156
#
#  dense_2 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 229
# Trainable params: 229
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 12)                84
#
#  dense_4 (Dense)             (None, 12)                156
#
#  dense_5 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 253
# Trainable params: 253
# Non-trainable params: 0
# _________________________________________________________________
# 2022-01-15 09:16:42.987578: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X_train_wO_elo = X_train.drop(['elo1_pre', 'elo2_pre'], axis = 1)

# %%
model_wO_elo.fit(X_train_wO_elo.values,
          y_train.values,
          verbose=1,
          shuffle=True,
          epochs=15,
          batch_size=512)

model.fit(X_train.values,
          y_train.values,
          verbose=1,
          shuffle=True,
          epochs=15,
          batch_size=512)
# Out:
# Epoch 1/15
# 6371/6371 [==============================] - 6s 788us/step - loss: 3.6358 - accuracy: 0.6735 - auc: 0.6892
# Epoch 2/15
# 6371/6371 [==============================] - 5s 711us/step - loss: 2.2999 - accuracy: 0.6757 - auc: 0.6984
# Epoch 3/15
# 6371/6371 [==============================] - 5s 707us/step - loss: 1.4122 - accuracy: 0.6797 - auc: 0.7144
# Epoch 4/15
# 6371/6371 [==============================] - 4s 698us/step - loss: 0.6956 - accuracy: 0.6943 - auc: 0.7619
# Epoch 5/15
# 6371/6371 [==============================] - 4s 696us/step - loss: 0.5357 - accuracy: 0.7175 - auc: 0.7969
# Epoch 6/15
# 6371/6371 [==============================] - 5s 740us/step - loss: 0.4957 - accuracy: 0.7374 - auc: 0.8217
# Epoch 7/15
# 6371/6371 [==============================] - 4s 698us/step - loss: 0.4927 - accuracy: 0.7395 - auc: 0.8241
# Epoch 8/15
# 6371/6371 [==============================] - 5s 746us/step - loss: 0.4918 - accuracy: 0.7399 - auc: 0.8247
# Epoch 9/15
# 6371/6371 [==============================] - 5s 731us/step - loss: 0.4913 - accuracy: 0.7397 - auc: 0.8250
# Epoch 10/15
# 6371/6371 [==============================] - 5s 714us/step - loss: 0.4911 - accuracy: 0.7402 - auc: 0.8252
# Epoch 11/15
# 6371/6371 [==============================] - 4s 703us/step - loss: 0.4908 - accuracy: 0.7402 - auc: 0.8253
# Epoch 12/15
# 6371/6371 [==============================] - 4s 693us/step - loss: 0.4906 - accuracy: 0.7404 - auc: 0.8255
# Epoch 13/15
# 6371/6371 [==============================] - 4s 691us/step - loss: 0.4907 - accuracy: 0.7403 - auc: 0.8254
# Epoch 14/15
# 6371/6371 [==============================] - 4s 689us/step - loss: 0.4909 - accuracy: 0.7403 - auc: 0.8254
# Epoch 15/15
# 6371/6371 [==============================] - 4s 692us/step - loss: 0.4910 - accuracy: 0.7403 - auc: 0.8254
# Epoch 1/15
# 6371/6371 [==============================] - 5s 689us/step - loss: 1.7391 - accuracy: 0.6849 - auc: 0.7360
# Epoch 2/15
# 6371/6371 [==============================] - 5s 710us/step - loss: 1.1772 - accuracy: 0.6912 - auc: 0.7556
# Epoch 3/15
# 6371/6371 [==============================] - 4s 687us/step - loss: 0.8978 - accuracy: 0.6939 - auc: 0.7661
# Epoch 4/15
# 6371/6371 [==============================] - 4s 685us/step - loss: 0.5768 - accuracy: 0.7224 - auc: 0.7986
# Epoch 5/15
# 6371/6371 [==============================] - 4s 687us/step - loss: 0.4793 - accuracy: 0.7546 - auc: 0.8394
# Epoch 6/15
# 6371/6371 [==============================] - 5s 768us/step - loss: 0.4724 - accuracy: 0.7597 - auc: 0.8447
# Epoch 7/15
# 6371/6371 [==============================] - 4s 704us/step - loss: 0.4669 - accuracy: 0.7638 - auc: 0.8488
# Epoch 8/15
# 6371/6371 [==============================] - 4s 690us/step - loss: 0.4646 - accuracy: 0.7649 - auc: 0.8500
# Epoch 9/15
# 6371/6371 [==============================] - 4s 689us/step - loss: 0.4640 - accuracy: 0.7650 - auc: 0.8504
# Epoch 10/15
# 6371/6371 [==============================] - 4s 691us/step - loss: 0.4635 - accuracy: 0.7652 - auc: 0.8506
# Epoch 11/15
# 6371/6371 [==============================] - 4s 687us/step - loss: 0.4632 - accuracy: 0.7651 - auc: 0.8507
# Epoch 12/15
# 6371/6371 [==============================] - 4s 705us/step - loss: 0.4629 - accuracy: 0.7652 - auc: 0.8509
# Epoch 13/15
# 6371/6371 [==============================] - 5s 720us/step - loss: 0.4627 - accuracy: 0.7653 - auc: 0.8511
# Epoch 14/15
# 6371/6371 [==============================] - 4s 688us/step - loss: 0.4625 - accuracy: 0.7656 - auc: 0.8512
# Epoch 15/15
# 6371/6371 [==============================] - 4s 703us/step - loss: 0.4622 - accuracy: 0.7655 - auc: 0.8514

# %%
model.save('../Models/TF_model_w_elo.h5')
model_wO_elo.save('../Models/TF_model_wO_elo.h5')

# %%
# model = tf.keras.models.load_model('../Models/TF_model_w_elo')
# model_wO_elo = tf.keras.models.load_model('../Models/TF_model_w0_elo')

# %%
X_train_wO_elo.columns
# Out:
# Index(['home_poss', 'diff', 'time_remaining', 'OT_ind'], dtype='object')

# %%
df.loc[:, 'preds_w_elo'] = model.predict_on_batch(df[X_train.columns])

df.loc[:, 'preds_wO_elo'] = model_wO_elo.predict_on_batch(df[X_train_wO_elo.columns])

# %%
db.list_collection_names()
# Out:
# ['historical_raptor',
#  'player2k',
#  'game_log',
#  'shot_chart',
#  'historical_pbp_modelled',
#  'historical_pbp']

# %%
db.historical_pbp_modelled.drop()

# %%
db.historical_pbp_modelled.insert_many(df.to_dict('records'))

# %%
test.loc[:, 'preds_w_elo'] = model.predict_on_batch(X_test[X_train.columns])

test.loc[:, 'preds_wO_elo'] = model_wO_elo.predict_on_batch(X_test[X_train_wO_elo.columns])
# Out:
# /Users/arun/Projects/NBA/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# /Users/arun/Projects/NBA/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
test
# Out:
#           GAME_ID  home_poss  diff  time_remaining  OT_ind     elo1_pre  \
# 3261524  22001028          0     1            2880       0  1541.747434
# 3261525  22001028          1     1            2880       0  1541.747434
# 3261526  22001028          1     1            2862       0  1541.747434
# 3261527  22001028          1     1            2858       0  1541.747434
# 3261528  22001028          1     2            2858       0  1541.747434
# ...           ...        ...   ...             ...     ...          ...
# 3553191  22100581          0    17              34       0  1694.385602
# 3553192  22100581          0    17              31       0  1694.385602
# 3553193  22100581          0    17              23       0  1694.385602
# 3553194  22100581          1    17              18       0  1694.385602
# 3553195  22100581          0    17               0       0  1694.385602
#
#             elo2_pre  elo_difference  home_team_win  preds_w_elo  preds_wO_elo
# 3261524  1501.032897       40.714537              1     0.584544      0.619525
# 3261525  1501.032897       40.714537              1     0.583709      0.622191
# 3261526  1501.032897       40.714537              1     0.584210      0.621330
# 3261527  1501.032897       40.714537              1     0.584321      0.621138
# 3261528  1501.032897       40.714537              1     0.601245      0.642050
# ...              ...             ...            ...          ...           ...
# 3553191  1490.689779      203.695823              1     0.999897      1.000000
# 3553192  1490.689779      203.695823              1     0.999899      1.000000
# 3553193  1490.689779      203.695823              1     0.999904      1.000000
# 3553194  1490.689779      203.695823              1     0.999905      1.000000
# 3553195  1490.689779      203.695823              1     0.999918      1.000000
#
# [291672 rows x 11 columns]

# %%
from sklearn.metrics import brier_score_loss

# %%
brier_score_loss(test['home_team_win'], test['preds_w_elo'])
# Out:
# 0.15495321224308004

# %%
brier_score_loss(test['home_team_win'], test['preds_wO_elo'])
# Out:
# 0.1654293641223685

# %%
test = test.merge(test.groupby('GAME_ID').apply(lambda x: brier_score_loss(x['home_team_win'], x['preds_wO_elo'])).rename('brier_loss_wO_elo').reset_index(),
          on=['GAME_ID'])

# %%
test = test.merge(test.groupby('GAME_ID').apply(lambda x: brier_score_loss(x['home_team_win'], x['preds_w_elo'])).rename('brier_loss_w_elo').reset_index(),
          on=['GAME_ID'])

# %%
test.loc[:, 'brier_loss_diff'] = np.abs(test['brier_loss_w_elo'] - test['brier_loss_wO_elo'])

# %%
test.sort_values(by='brier_loss_diff', ascending=False)
# Out:
#          GAME_ID  home_poss  diff  time_remaining  OT_ind     elo1_pre  \
# 24511   22001074          0    -2             721       0  1227.838160
# 24469   22001074          0    -7            1029       0  1227.838160
# 24480   22001074          0    -6             984       0  1227.838160
# 24479   22001074          1    -6             987       0  1227.838160
# 24478   22001074          0    -6            1000       0  1227.838160
# ...          ...        ...   ...             ...     ...          ...
# 208882  22100393          0     9            1923       0  1541.258272
# 208881  22100393          1    11            1931       0  1541.258272
# 208880  22100393          1    11            1931       0  1541.258272
# 208879  22100393          1    11            1944       0  1541.258272
# 209211  22100393          0    14               0       0  1541.258272
#
#            elo2_pre  elo_difference  home_team_win  preds_w_elo  preds_wO_elo  \
# 24511   1633.740769      405.902610              1     0.195942      0.509828
# 24469   1633.740769      405.902610              1     0.108807      0.303200
# 24480   1633.740769      405.902610              1     0.115584      0.327696
# 24479   1633.740769      405.902610              1     0.115119      0.324217
# 24478   1633.740769      405.902610              1     0.116460      0.330497
# ...             ...             ...            ...          ...           ...
# 208882  1431.180174      110.078098              1     0.818704      0.815451
# 208881  1431.180174      110.078098              1     0.843198      0.859752
# 208880  1431.180174      110.078098              1     0.843198      0.859752
# 208879  1431.180174      110.078098              1     0.842547      0.859111
# 209211  1431.180174      110.078098              1     0.999576      1.000000
#
#         brier_loss_wO_elo  brier_loss_w_elo  brier_loss_diff
# 24511            0.163852          0.544678         0.380826
# 24469            0.163852          0.544678         0.380826
# 24480            0.163852          0.544678         0.380826
# 24479            0.163852          0.544678         0.380826
# 24478            0.163852          0.544678         0.380826
# ...                   ...               ...              ...
# 208882           0.018846          0.018787         0.000059
# 208881           0.018846          0.018787         0.000059
# 208880           0.018846          0.018787         0.000059
# 208879           0.018846          0.018787         0.000059
# 209211           0.018846          0.018787         0.000059
#
# [291672 rows x 14 columns]

# %%
live_pbp = test[['GAME_ID', 'home_poss', 'diff', 'time_remaining', 'OT_ind', 'preds_wO_elo']]

# %%
live_pbp.columns = ['game_id', 'home_poss', 'diff', 'time_remaining', 'OT_ind', 'prob']

# %%
import sqlite3 as sq

conn = sq.connect('../Data/NBA.sqlite')
live_pbp.to_sql('live_pbp', conn, if_exists = 'replace', index=False)

# %%
test_game = test[test['GAME_ID'] == 22001074]

# %%
plot_data = test_game[['time_remaining', 'preds_w_elo', 'preds_wO_elo']]

# %%
plot_data.plot(y='preds_wO_elo', ylim=[0,1])
# Out:
# <AxesSubplot:>

# %%
from nba_api.stats.endpoints import winprobabilitypbp

pbpw = winprobabilitypbp.WinProbabilityPBP('0022001074').get_data_frames()

# %%
pbpw[0].HOME_PCT.plot(ylim = [0,1])
# Out:
# <AxesSubplot:>

# %%
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = 'iframe'

# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(x = test_game['time_remaining'][::-1], y=test_game['preds_w_elo'],
                    mode='lines', name='win prob with elo'))

fig.add_trace(go.Scatter(x = test_game['time_remaining'][::-1], y=test_game['preds_wO_elo'],
                    mode='lines', name='win prob'))

fig.add_vline(x=720, line_width=3, line_dash="dash", line_color="green", name='Q1')
fig.add_vline(x=1440, line_width=3, line_dash="dash", line_color="green", name='Q1')
fig.add_vline(x=2160, line_width=3, line_dash="dash", line_color="green", name='Q1')



fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_63.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
from nba_api.stats.endpoints import playbyplayv2

pbp = playbyplayv2.PlayByPlayV2('0022100525').get_data_frames()[0]

pbp
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0    0022100525         2            12                   0       1
# 1    0022100525         4            10                   0       1
# 2    0022100525        49             5                   2       1
# 3    0022100525        10             2                   6       1
# 4    0022100525        11             4                   0       1
# ..          ...       ...           ...                 ...     ...
# 471  0022100525       689             2                   1       4
# 472  0022100525       691             4                   0       4
# 473  0022100525       692             2                   1       4
# 474  0022100525       693             4                   0       4
# 475  0022100525       694            13                   0       4
#
#     WCTIMESTRING PCTIMESTRING                              HOMEDESCRIPTION  \
# 0        7:12 PM        12:00                                         None
# 1        7:12 PM        12:00  Jump Ball Aldridge vs. Embiid: Tip to Curry
# 2        7:12 PM        11:42                         Harden STEAL (1 STL)
# 3        7:12 PM        11:36                 MISS Harden 5' Driving Layup
# 4        7:12 PM        11:34                Claxton REBOUND (Off:1 Def:0)
# ..           ...          ...                                          ...
# 471      9:23 PM         0:05                MISS Harden 26' 3PT Jump Shot
# 472      9:23 PM         0:01                Harden REBOUND (Off:3 Def:11)
# 473      9:23 PM         0:00                   MISS Aldridge 6' Jump Shot
# 474      9:23 PM         0:00                                         None
# 475      9:23 PM         0:00                                         None
#
#                     NEUTRALDESCRIPTION                 VISITORDESCRIPTION  \
# 0    Start of 1st Period (7:12 PM EST)                               None
# 1                                 None                               None
# 2                                 None  Embiid Lost Ball Turnover (P1.T1)
# 3                                 None                               None
# 4                                 None                               None
# ..                                 ...                                ...
# 471                               None             Thybulle BLOCK (2 BLK)
# 472                               None                               None
# 473                               None                               None
# 474                               None       Embiid REBOUND (Off:2 Def:5)
# 475    End of 4th Period (9:23 PM EST)                               None
#
#          SCORE SCOREMARGIN  PERSON1TYPE  PLAYER1_ID       PLAYER1_NAME  \
# 0         None        None            0           0               None
# 1         None        None            4      200746  LaMarcus Aldridge
# 2         None        None            5      203954        Joel Embiid
# 3         None        None            4      201935       James Harden
# 4         None        None            4     1629651        Nic Claxton
# ..         ...         ...          ...         ...                ...
# 471       None        None            4      201935       James Harden
# 472       None        None            4      201935       James Harden
# 473       None        None            4      200746  LaMarcus Aldridge
# 474       None        None            5      203954        Joel Embiid
# 475  110 - 102          -8            0           0               None
#
#      PLAYER1_TEAM_ID PLAYER1_TEAM_CITY PLAYER1_TEAM_NICKNAME  \
# 0                NaN              None                  None
# 1       1.610613e+09          Brooklyn                  Nets
# 2       1.610613e+09      Philadelphia                 76ers
# 3       1.610613e+09          Brooklyn                  Nets
# 4       1.610613e+09          Brooklyn                  Nets
# ..               ...               ...                   ...
# 471     1.610613e+09          Brooklyn                  Nets
# 472     1.610613e+09          Brooklyn                  Nets
# 473     1.610613e+09          Brooklyn                  Nets
# 474     1.610613e+09      Philadelphia                 76ers
# 475              NaN              None                  None
#
#     PLAYER1_TEAM_ABBREVIATION  PERSON2TYPE  PLAYER2_ID  PLAYER2_NAME  \
# 0                        None            0           0          None
# 1                         BKN            5      203954   Joel Embiid
# 2                         PHI            4      201935  James Harden
# 3                         BKN            0           0          None
# 4                         BKN            0           0          None
# ..                        ...          ...         ...           ...
# 471                       BKN            0           0          None
# 472                       BKN            0           0          None
# 473                       BKN            0           0          None
# 474                       PHI            0           0          None
# 475                      None            0           0          None
#
#      PLAYER2_TEAM_ID PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME  \
# 0                NaN              None                  None
# 1       1.610613e+09      Philadelphia                 76ers
# 2       1.610613e+09          Brooklyn                  Nets
# 3                NaN              None                  None
# 4                NaN              None                  None
# ..               ...               ...                   ...
# 471              NaN              None                  None
# 472              NaN              None                  None
# 473              NaN              None                  None
# 474              NaN              None                  None
# 475              NaN              None                  None
#
#     PLAYER2_TEAM_ABBREVIATION  PERSON3TYPE  PLAYER3_ID      PLAYER3_NAME  \
# 0                        None            0           0              None
# 1                         PHI            5      203552        Seth Curry
# 2                         BKN            0           0              None
# 3                        None            0           0              None
# 4                        None            0           0              None
# ..                        ...          ...         ...               ...
# 471                      None            5     1629680  Matisse Thybulle
# 472                      None            0           0              None
# 473                      None            0           0              None
# 474                      None            0           0              None
# 475                      None            0           0              None
#
#      PLAYER3_TEAM_ID PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 0                NaN              None                  None
# 1       1.610613e+09      Philadelphia                 76ers
# 2                NaN              None                  None
# 3                NaN              None                  None
# 4                NaN              None                  None
# ..               ...               ...                   ...
# 471     1.610613e+09      Philadelphia                 76ers
# 472              NaN              None                  None
# 473              NaN              None                  None
# 474              NaN              None                  None
# 475              NaN              None                  None
#
#     PLAYER3_TEAM_ABBREVIATION  VIDEO_AVAILABLE_FLAG
# 0                        None                     0
# 1                         PHI                     1
# 2                        None                     1
# 3                        None                     1
# 4                        None                     1
# ..                        ...                   ...
# 471                       PHI                     1
# 472                      None                     1
# 473                      None                     1
# 474                      None                     1
# 475                      None                     1
#
# [476 rows x 34 columns]

# %%
from preprocess import *

# %%
elo.query("date == '2021-12-30'")
# Out:
#              date team1     elo1_pre     elo2_pre  elo_difference
# 71234  2021-12-30   BRK  1611.241573  1576.527816       34.713757
# 71235  2021-12-30   ORL  1310.797644  1609.221441      298.423798
# 71236  2021-12-30   WAS  1461.068662  1591.958200      130.889538

# %%
recent_game = feature_engineer(pbp).assign(elo1_pre = 1611.241573, elo2_pre = 1576.527816)

# %%
recent_game = recent_game[X_train.columns]

# %%
recent_game_wO_elo = recent_game[X_train_wO_elo.columns]

# %%
recent_game.loc[:, 'preds_w_elo'] = model.predict_on_batch(recent_game[X_train.columns])

recent_game.loc[:, 'preds_wO_elo'] = model_wO_elo.predict_on_batch(recent_game[X_train_wO_elo.columns])
# Out:
# /Users/arun/Projects/NBA/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/arun/Projects/NBA/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(x = test_game['time_remaining'][::-1], y=test_game['preds_w_elo'],
                    mode='lines', name='win prob with elo'))

fig.add_trace(go.Scatter(x = test_game['time_remaining'][::-1], y=test_game['preds_wO_elo'],
                    mode='lines', name='win prob'))

fig.add_vline(x=720, line_width=3, line_dash="dash", line_color="green", name='Q1')
fig.add_vline(x=1440, line_width=3, line_dash="dash", line_color="green", name='Q1')
fig.add_vline(x=2160, line_width=3, line_dash="dash", line_color="green", name='Q1')



fig.show()

# %%
def plot_game(df):
    # Create traces
    fig = go.Figure()
    fig.add_trace(go.Scatter(x = df['time_remaining'][::-1], y=df['preds_w_elo'],
                        mode='lines', name='win prob with elo'))

    fig.add_trace(go.Scatter(x = df['time_remaining'][::-1], y=df['preds_wO_elo'],
                        mode='lines', name='win prob'))

    fig.add_vline(x=720, line_width=3, line_dash="dash", line_color="green", name='Q1')
    fig.add_vline(x=1440, line_width=3, line_dash="dash", line_color="green", name='Q1')
    fig.add_vline(x=2160, line_width=3, line_dash="dash", line_color="green", name='Q1')



    fig.show()

# %%
plot_game(recent_game)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_20.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
'''
how to do this! 

you need to continuously call the api and sleep accordingly depending on timeout/half time etc

when you call the api compare it with the most recent json you have 
if the json are the same
leave it
if theyre not the same then make sure you push the new json to the database and make the curr_json the new json to compare w for future api calls

on the other side create an event to say when the database updates trigger an event to update the win probabilities and subsequently plot the graphs'''
