# %%
import pandas as pd
from pymongo import MongoClient

client = MongoClient('localhost', 27017)
db = client['NBA']

db.list_collection_names()
# Out:
# ['historical_raptor',
#  'player2k',
#  'shot_chart',
#  'game_log',
#  'historical_pbp_modelled',
#  'historical_pbp']

# %%
pd.DataFrame.from_records(db.historical_pbp.find({'GAME_ID': 22100581}))
# Out:
#                           _id   GAME_ID  EVENTNUM  EVENTMSGTYPE  \
# 0    61ea2de5abac825b55d16c0d  22100581         2            12
# 1    61ea2de5abac825b55d16c0e  22100581         4            10
# 2    61ea2de5abac825b55d16c0f  22100581         7             2
# 3    61ea2de5abac825b55d16c10  22100581         8             4
# 4    61ea2de5abac825b55d16c11  22100581         9             2
# ..                        ...       ...       ...           ...
# 471  61ea2de5abac825b55d16de4  22100581       666             2
# 472  61ea2de5abac825b55d16de5  22100581       667             4
# 473  61ea2de5abac825b55d16de6  22100581       669             2
# 474  61ea2de5abac825b55d16de7  22100581       670             4
# 475  61ea2de5abac825b55d16de8  22100581       671            13
#
#      EVENTMSGACTIONTYPE  PERIOD WCTIMESTRING PCTIMESTRING  \
# 0                     0       1     10:03 PM        12:00
# 1                     0       1     10:03 PM        12:00
# 2                   101       1     10:03 PM        11:44
# 3                     0       1     10:03 PM        11:41
# 4                     1       1     10:04 PM        11:18
# ..                  ...     ...          ...          ...
# 471                   1       4     12:15 AM         0:34
# 472                   0       4     12:15 AM         0:31
# 473                   1       4     12:15 AM         0:23
# 474                   0       4     12:15 AM         0:18
# 475                   0       4     12:15 AM         0:00
#
#                                HOMEDESCRIPTION  \
# 0                                         None
# 1    Jump Ball Smith vs. Ibaka: Tip to Johnson
# 2    MISS Smith 11' Driving Floating Jump Shot
# 3                                         None
# 4                                         None
# ..                                         ...
# 471                                       None
# 472                                       None
# 473                                       None
# 474                 Bass REBOUND (Off:1 Def:1)
# 475                                       None
#
#                      NEUTRALDESCRIPTION  ... PLAYER2_TEAM_NICKNAME  \
# 0    Start of 1st Period (10:03 PM EST)  ...                  None
# 1                                  None  ...              Clippers
# 2                                  None  ...                  None
# 3                                  None  ...                  None
# 4                                  None  ...                  None
# ..                                  ...  ...                   ...
# 471                                None  ...                  None
# 472                                None  ...                  None
# 473                                None  ...                  None
# 474                                None  ...                  None
# 475    End of 4th Period (12:15 AM EST)  ...                  None
#
#     PLAYER2_TEAM_ABBREVIATION PERSON3TYPE  PLAYER3_ID     PLAYER3_NAME  \
# 0                        None           0           0             None
# 1                         LAC           4     1629661  Cameron Johnson
# 2                        None           0           0             None
# 3                        None           0           0             None
# 4                        None           0           0             None
# ..                        ...         ...         ...              ...
# 471                      None           0           0             None
# 472                      None           0           0             None
# 473                      None           0           0             None
# 474                      None           0           0             None
# 475                      None           0           0             None
#
#     PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 0               NaN               None                  None
# 1      1.610613e+09            Phoenix                  Suns
# 2               NaN               None                  None
# 3               NaN               None                  None
# 4               NaN               None                  None
# ..              ...                ...                   ...
# 471             NaN               None                  None
# 472             NaN               None                  None
# 473             NaN               None                  None
# 474             NaN               None                  None
# 475             NaN               None                  None
#
#     PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG
# 0                        None                    0
# 1                         PHX                    1
# 2                        None                    1
# 3                        None                    1
# 4                        None                    1
# ..                        ...                  ...
# 471                      None                    1
# 472                      None                    0
# 473                      None                    1
# 474                      None                    1
# 475                      None                    1
#
# [476 rows x 35 columns]

# %%
historical_pbp = pd.DataFrame.from_records(db.historical_pbp.find())

# %%
historical_pbp_modelled = pd.DataFrame.from_records(db.historical_pbp_modelled.find())

# %%
game_log = pd.DataFrame.from_records(db.game_log.find())

# %%
historical_pbp.to_csv('historical_pbp.csv', index=False)
historical_pbp_modelled.to_csv('historical_pbp_modelled.csv', index=False)
game_log.to_csv('game_log.csv', index=False)

# %%
# 
# db.list_collection_names()

# %%
db = client['NBA']

# %%
data = pd.read_csv('historical_pbp.csv', chunksize=5000)

# %%
for chunk in data:
    print(chunk.shape)
# Out:
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# (5000, 35)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/6n/_mn7r8yx4fd_kqsrk0pcy6hc0000gn/T/ipykernel_11789/2429991452.py in <module>
# ----> 1 for chunk in data:
#       2     print(chunk.shape)
#
# ~/Projects/NBA/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __next__(self)
#    1022     def __next__(self):
#    1023         try:
# -> 1024             return self.get_chunk()
#    1025         except StopIteration:
#    1026             self.close()
#
# ~/Projects/NBA/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py in get_chunk(self, size)
#    1072                 raise StopIteration
#    1073             size = min(size, self.nrows - self._currow)
# -> 1074         return self.read(nrows=size)
#    1075
#    1076     def __enter__(self):
#
# ~/Projects/NBA/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~/Projects/NBA/venv/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~/Projects/NBA/venv/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~/Projects/NBA/venv/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~/Projects/NBA/venv/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# ~/Projects/NBA/venv/lib/python3.9/site-packages/pandas/core/dtypes/common.py in is_extension_array_dtype(arr_or_dtype)
#    1418
#    1419
# -> 1420 def is_extension_array_dtype(arr_or_dtype) -> bool:
#    1421     """
#    1422     Check if an object is a pandas extension array type.
#
# KeyboardInterrupt:

# %%
# from pymongo import MongoClient, ASCENDING, DESCENDING

# db.game_log.insert_many(all_games.to_dict('records'))

# db.game_log.create_index([("GAME_ID", ASCENDING)], unique=True)
